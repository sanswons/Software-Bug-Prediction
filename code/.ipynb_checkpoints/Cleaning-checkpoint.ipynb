# %%
# !pip install pandas --user
# !pip install glob --user
# !pip install toolz --user
# Out:
# Requirement already satisfied: pandas in /hb/home/swoonna/.local/lib/python3.6/site-packages (0.23.4)
# Requirement already satisfied: pytz>=2011k in /hb/home/swoonna/.local/lib/python3.6/site-packages (from pandas) (2018.9)
# Requirement already satisfied: python-dateutil>=2.5.0 in /hb/home/swoonna/anaconda3/envs/sbp/lib/python3.6/site-packages (from pandas) (2.7.5)
# Requirement already satisfied: numpy>=1.9.0 in /hb/home/swoonna/.local/lib/python3.6/site-packages (from pandas) (1.15.4)
# Requirement already satisfied: six>=1.5 in /hb/home/swoonna/anaconda3/envs/sbp/lib/python3.6/site-packages (from python-dateutil>=2.5.0->pandas) (1.12.0)
# Collecting glob
#   Could not find a version that satisfies the requirement glob (from versions: )
# No matching distribution found for glob
# Requirement already satisfied: toolz in /hb/home/swoonna/.local/lib/python3.6/site-packages (0.9.0)

# %%
import os
import glob
from collections import defaultdict
import pandas as pd

# %% [markdown]
# ### Find all repositories

# %%
data_repos = glob.glob('../data/*')
print(data_repos)
# Out:
# ['../data/ParlAI', '../data/keras', '../data/tensor2tensor', '../data/fastText', '../data/Horizon', '../data/pytext', '../data/Detectron']

# %% [markdown]
# ### Save all filenames of each repo in a dictionary

# %%
repo_files_dict = defaultdict(list)
for repo in data_repos:
    filenames = glob.glob(repo + '/**/*.py',recursive=True)
    repo_files_dict[repo] = filenames
print(len(repo_files_dict))
# Out:
# 7

# %% [markdown]
# ### Create Pandas dataframe to store repo name and their python files

# %%
repos_df = defaultdict(list)
for repo, filenames in repo_files_dict.items():
    code = ''
    for filename in filenames:
        code += filename + '\n'
        file = open(filename,'r')
        code += file.read()
    repos_df['repo_name'].append(repo)
    repos_df['code'].append(code)

repos_df = pd.DataFrame.from_dict(repos_df)

# %% [markdown]
# ## Create vocabulary for Encoder
# ### Refer https://arxiv.org/pdf/1508.07909.pdf

# %%
from encoder import *
import pickle

# %%
corpus = ' <\eol>\n'.join(repos_df['code'])
corpus[:1000]
# Out:
# '../data/ParlAI/setup.py\n#!/usr/bin/env python3\n\n# Copyright (c) 2017-present, Facebook, Inc.\n# All rights reserved.\n# This source code is licensed under the BSD-style license found in the\n# LICENSE file in the root directory of this source tree. An additional grant\n# of patent rights can be found in the PATENTS file in the same directory.\n\n\nfrom setuptools import setup, find_packages\nimport sys\n\nif sys.version_info < (3,):\n    sys.exit(\'Sorry, Python 3 is required for ParlAI.\')\n\nwith open(\'README.md\', encoding="utf8") as f:\n    readme = f.read()\n\nwith open(\'LICENSE\') as f:\n    license = f.read()\n\nwith open(\'requirements.txt\') as f:\n    reqs = f.read()\n\nsetup(\n    name=\'parlai\',\n    version=\'0.1.0\',\n    description=\'Unified API for accessing dialog datasets.\',\n    long_description=readme,\n    url=\'http://parl.ai/\',\n    license=license,\n    packages=find_packages(exclude=(\n        \'data\', \'docs\', \'downloads\', \'examples\', \'logs\', \'tests\')),\n    install_requires=reqs.strip().split(\'\\n\'),\n '

# %%
# %%bash
# rm -rf data/lang_gen
# mkdir -p data/lang_gen/

# %%
ofp = open('data/lang_gen/raw.txt',"w") 
ofp.write(corpus)
# Out:
# 12039974

# %%
# !wc -l data/lang_gen/*.txt
# Out:
# 325501 data/lang_gen/raw.txt

# %% [markdown]
# ## Encoding

# %%
encoder = Encoder(40000, pct_bpe=0.88,ngram_min=1,ngram_max=5)
encoder.fit(corpus.split('\n'))

# %%
example = "def trim_vocab(n, vocab):\n# type: (int, Dict[str, int]) -> None\n''' Deletes all pairs below 10 * vocab size to prevent memory problems '''\npair_counts = sorted(vocab.items(), key=lambda p: -p[1])\npairs_to_trim = [pair for pair, count in pair_counts[n:]]\nfor pair in pairs_to_trim:\ndel vocab[pair]"
print(encoder.tokenize(example))
print(next(encoder.transform([example])))
print(next(encoder.inverse_transform(encoder.transform([example]))))
# Out:
# ['def', '__sow', 'tri', 'm_v', 'ocab', '__eow', '(', 'n', ',', 'vocab', '):', '#', 'type', ':', '(', 'int', ',', 'dict', '[', 'str', ',', 'int', '])', '->', 'none', "'''", '__sow', 'delet', 'es', '__eow', 'all', 'pairs', 'below', '10', '*', 'vocab', 'size', 'to', 'prevent', 'memory', '__sow', 'probl', 'ems', '__eow', "'''", '__sow', 'pair_', 'count', 's', '__eow', '=', 'sorted', '(', 'vocab', '.', 'items', '(),', 'key', '=', 'lambda', 'p', ':', '-', 'p', '[', '1', '])', '__sow', 'pairs', '_to_t', 'rim', '__eow', '=', '[', 'pair', 'for', 'pair', ',', 'count', 'in', '__sow', 'pair_', 'count', 's', '__eow', '[', 'n', '__sow', ':]]', '__eow', 'for', 'pair', 'in', '__sow', 'pairs', '_to_t', 'rim', '__eow', ':', 'del', 'vocab', '[', 'pair', ']']
# [21, 4800, 5056, 15476, 6526, 4801, 3, 96, 4, 458, 16, 10, 74, 8, 3, 104, 4, 108, 14, 109, 4, 104, 124, 237, 35, 405, 4800, 10464, 4833, 4801, 71, 1652, 861, 354, 80, 458, 136, 30, 2815, 557, 4800, 27696, 10064, 4801, 405, 4800, 18518, 724, 91, 4801, 5, 905, 3, 458, 2, 317, 182, 260, 5, 521, 210, 8, 23, 210, 14, 18, 124, 4800, 1652, 12176, 13298, 4801, 5, 14, 1336, 19, 1336, 4, 724, 12, 4800, 18518, 724, 91, 4801, 14, 96, 4800, 38722, 4801, 19, 1336, 12, 4800, 1652, 12176, 13298, 4801, 8, 1181, 458, 14, 1336, 26]
# def trim_vocab ( n , vocab ): # type : ( int , dict [ str , int ]) -> none ''' deletes all pairs below 10 * vocab size to prevent memory problems ''' pair_counts = sorted ( vocab . items (), key = lambda p : - p [ 1 ]) pairs_to_trim = [ pair for pair , count in pair_counts [ n :]] for pair in pairs_to_trim : del vocab [ pair ]

